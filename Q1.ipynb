# %%
import networkx as nx

# Load the GraphML file
G = nx.read_graphml(r'B:\Final Network Science Project\Data\grpah file\Shipping_Network.graphml')

# Print number of nodes and edges
print("Number of nodes:", G.number_of_nodes())
print("Number of edges:", G.number_of_edges())
# Out:
# Number of nodes: 908
# Number of edges: 12749

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Load the GraphML file
G = nx.read_graphml(r'B:\Final Network Science Project\Data\grpah file\Shipping_Network.graphml')

degrees = [d for n, d in G.degree()]  # Undirected degree

# Plot the degree distribution
plt.figure(figsize=(10, 6))
plt.hist(degrees, bins=range(1, max(degrees)+2), edgecolor='black', color='skyblue', align='left')
plt.title("Degree Distribution of Shipping Network")
plt.xlabel("Degree")
plt.ylabel("Number of Nodes")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# Load the GraphML file
G = nx.read_graphml(r'B:\Final Network Science Project\Data\grpah file\Shipping_Network.graphml')

# Degree list
degrees = [d for n, d in G.degree()]
degree_counts = np.bincount(degrees)

# Prepare data for log-log plot
degree_vals = np.nonzero(degree_counts)[0]
counts = degree_counts[degree_vals]

# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(degree_vals, counts, color='blue', edgecolors='k', alpha=0.7)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Degree (log scale)', fontsize=12)
plt.ylabel('Number of Nodes (log scale)', fontsize=12)
plt.title('Log-Log Degree Distribution of Shipping Network', fontsize=14)
plt.grid(True, which="both", ls="--", linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# Load the graph
G = nx.read_graphml(r'B:\Final Network Science Project\Data\grpah file\Shipping_Network.graphml')

# Extract degrees
degrees = [d for n, d in G.degree()]
degrees = np.array(degrees)

# Filter out zeros if any
degrees = degrees[degrees > 0]

# Define log-spaced bins for log-binning
min_deg = degrees.min()
max_deg = degrees.max()
num_bins = 100  # increase for smoother curve
bins = np.logspace(np.log10(min_deg), np.log10(max_deg), num=num_bins)

# Histogram (log-binned)
hist, bin_edges = np.histogram(degrees, bins=bins, density=True)
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

# Plot
plt.figure(figsize=(10, 6))
plt.loglog(bin_centers, hist, marker='o', linestyle='None', color='crimson', alpha=0.8)

# Labels and grid
plt.xlabel('Degree (log scale)', fontsize=13)
plt.ylabel('Probability (log scale)', fontsize=13)
plt.title('Log-Log Degree Distribution with Log-Binning', fontsize=14)
plt.grid(True, which="both", linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

# Load the GraphML file
G = nx.read_graphml(r'B:\Final Network Science Project\Data\grpah file\Shipping_Network.graphml')

# Degree list (excluding 0-degree nodes)
degrees = np.array([d for n, d in G.degree()])
degrees = degrees[degrees > 0]

# Set minimum degree (k_min) for power-law fit
k_min = np.min(degrees)

# MLE formula to estimate gamma
n = len(degrees)
gamma = 1 + n / np.sum(np.log(degrees / k_min))

print(f"Estimated power-law exponent (gamma): {gamma:.4f}")
# Out:
# Estimated power-law exponent (gamma): 1.8395

# %%
G = nx.read_graphml(r'B:\Final Network Science Project\Data\grpah file\Shipping_Network.graphml')

# Get all degrees as a list
degrees = [d for _, d in G.degree()]

# Compute statistics
avg_degree = sum(degrees) / len(degrees)
min_degree = min(degrees)
max_degree = max(degrees)

# Print results
print(f"Average Degree: {avg_degree:.2f}")
print(f"Minimum Degree: {min_degree}")
print(f"Maximum Degree: {max_degree}")
# Out:
# Average Degree: 28.08
# Minimum Degree: 4
# Maximum Degree: 907
